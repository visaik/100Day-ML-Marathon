# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, ybar):
    """
    Input y and ybar, calculate the MSE
    """
    
    mse = sum((y - ybar)**2) / len(y)
    
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 177.495
# The Mean absolute error is 10.752

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 尋找的資料: https://www.kaggle.com/c/shelter-animal-outcomes
# Shelter animal outcome
#
# 1. 你選的這組資料為何重要
# 這組資料記錄了收容所動物的資料，藉由分析這份資料，我們或許可以讓更多收容所內的動物找到主人，改善流浪動物的問題
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 美國Austin的動物收容所，收容所的人員記錄一段時間之內，收容所內的動物的特性，和收容所動物最後的結果
#
# 3. 蒐集而來的資料型態為何
# 資料均為字串，包含動物的種類(狗、貓)，性別、有無結紮、顏色、種類、年齡(用year, month, week, day字串表示)
# 結果也是字串，包含收養、還給原主人、轉送其他收容所、死亡和安樂死
#
# 4. 這組資料想解決的問題如何評估
# 我們可以預測，或分析什麼樣特性的動物比較容易被人領養，什麼樣特性的動物比較容易死亡
# 藉由預測出來的結果，我們可以知道什麼樣的動物需要多費心照顧，或這是加強某些動物的特性，讓他們比較容易被收養
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績的定義，指的是累積時間內，提升載客數量 X 客人付的費用
# 所以我們可以藉由提升客人數量，或讓客人付較多費用(搭到比較遠的地方、夜間加成)來提升業績
#
# 我們可以假設: 1 某些地點的載客總業績，較其他地點好
# 2 某些時間內的總業績，較其他時間好
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料可以蒐機每位司機每天的載客時段、車程時間、上車、下車的地點
# 可以藉由車子的跳表，和GPS來蒐集這些資料
#
# 另外，當天的天氣，是否是假日，有無舉行特別的活動，也可能影響業績
# 這些資料，可以藉由google來蒐集
#
# 3. 蒐集而來的資料型態為何
# 時間類的會是數值資料，地點也是數值資料(座標)，其他天氣、是否假日、有無活動為字串資料
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 關於地點的假設，我們可以分析不同地點，在單位時間內的總業績，藉由比較，確定業績和地點是否有關
# 關於時間的假設，我們同樣分析不同時間，計算全部地點的總業績，比較不同時間的結果是否有差異
